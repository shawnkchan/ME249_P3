# %%
# 2.1 a)

import math, numpy
import statistics
#Part 2 input data: Mode number, Air temp (degC), ID (W/sqm), load resistance (ohms)
# - split into training and validation sets 
xdata = [[0., 10.0, 200.0, 24.3], 
 [1., 10.0, 200.0, 24.3], 
 [2., 10.0, 200.0, 24.3], 
 [0., 10.0, 200.0, 51.8], 
 [1., 10.0, 200.0, 51.8],
         
 [2., 10.0, 200.0, 51.8], 
 [0., 10.0, 200.0, 96.2], 
 [1., 10.0, 200.0, 96.2], 
 [2., 10.0, 200.0, 96.2], 
 [0., 10.0, 200.0, 170.1],
         
 [1., 10.0, 200.0, 170.1], 
 [2., 10.0, 200.0, 170.1], 
 [0., 10.0, 500.0, 7.0], 
 [1., 10.0, 500.0, 7.0], 
 [2., 10.0, 500.0, 7.0], 
         
 [0., 10.0, 500.0, 21.2], 
 [1., 10.0, 500.0, 21.2], 
 [2., 10.0, 500.0, 21.2], 
 [0., 10.0, 500.0, 43.2], 
 [1., 10.0, 500.0, 43.2], 
         
 [1., 10.0, 700.0, 4.9], 
 [2., 10.0, 700.0, 4.9], 
 [0., 10.0, 700.0, 14.3], 
 [1., 10.0, 700.0, 14.3], 
 [2., 10.0, 700.0, 14.3],
         
 [2., 10.0, 500.0, 43.2], 
 [0., 10.0, 500.0, 79.1], 
 [1., 10.0, 500.0, 79.1], 
 [2., 10.0, 500.0, 79.1], 
 [0., 10.0, 700.0, 4.8], 
         
 [0., 10.0, 700.0, 29.7], 
 [1., 10.0, 700.0, 29.7], 
 [2., 10.0, 700.0, 29.7], 
 [0., 10.0, 700.0, 55.3], 
 [1., 10.0, 700.0, 55.3], 
 [2., 10.0, 700.0, 55.3], 
         
 [0., 10.0, 1000.0, 3.92], 
 [1., 10.0, 1000.0, 3.92], 
 [2., 10.0, 1000.0, 3.92], 
 [0., 10.0, 1000.0, 11.7], 
 [1., 10.0, 1000.0, 11.7], 
         
 [2., 10.0, 1000.0, 11.7], 
 [0., 10.0, 1000.0, 25.2], 
 [1., 10.0, 1000.0, 25.2], 
 [2., 10.0, 1000.0, 25.2], 
 [0., 10.0, 1000.0, 41.6], 
 [1., 10.0, 1000.0, 41.6], 
 [2., 10.0, 1000.0, 41.6]]

#Part 2 output data for above specified Mode and conditons: VL (V) and Power out (W)
ydata = [[46.0, 87.3], 
         [27.9, 64.2], 
         [27.9, 32.1], 
         [46.0, 40.9], 
         [92.1, 163.9], 
         [59.5, 68.5], 
         [46.0, 22.0], 
         [92.1, 88.2], 
         [110.6, 127.2], 
         [46.0, 12.4], 
         [92.1, 49.9], 
         [184.2, 199.6], 
         [48.4, 335.3], 
         [20.8, 124.3], 
         [20.8, 62.1], 
         [48.4, 110.7], 
         [96.8, 442.9], 
         [63.1, 188.2], 
         [48.4, 54.3], 
         [96.9, 217.3], 
         [128.7, 383.6], 
         [48.4, 29.6], 
         [96.8, 118.7], 
         [193.7, 474.8], 
         [49.3, 496.1], 
         [20.4, 171.2], 
         [20.4, 85.6], 
         [49.3, 169.9], 
         [98.6, 679.9], 
         [59.7, 249.8], 
         [49.3, 81.8], 
         [98.6, 327.4], 
         [124.1, 518.9], 
         [49.305, 43.9], 
         [98.6, 175.8], 
         [197.2, 703.3], 
         [50.8, 658.9], 
         [23.1, 272.9], 
         [23.1, 136.4], 
         [50.8, 220.7], 
         [101.6, 883.1], 
         [69.0, 407.2], 
         [50.8, 102.5], 
         [101.6, 410.0], 
         [148.6, 877.2], 
         [50.8, 62.0], 
         [101.6, 248.3], 
         [203.2, 993.5]]


print (xdata)
print (ydata)

xarray= numpy.array(xdata)
yarray= numpy.array(ydata)

Tall = [row[1] for row in xdata]
Tmed=statistics.median(Tall)
Iall = [row[2] for row in xdata]
Imed=statistics.median(Iall)
Rall = [row[2] for row in xdata]
Rmed=statistics.median(Rall)

Vall = [row[0] for row in ydata]
Vmed=statistics.median(Vall)
Wall = [row[0] for row in ydata]
Wmed=statistics.median(Wall)

xdata = []
ydata = []
ND = len(xarray)
for i in range(ND):
    xdata.append([xarray[i,0],xarray[i,1]/Tmed,xarray[i,2]/Imed,xarray[i,3]/Rmed])
    ydata.append([yarray[i,0]/Vmed,yarray[i,1]/Wmed])

xarray= numpy.array(xdata)
yarray= numpy.array(ydata)
print (xarray)
print (yarray)
# Out:
# [[0.0, 10.0, 200.0, 24.3], [1.0, 10.0, 200.0, 24.3], [2.0, 10.0, 200.0, 24.3], [0.0, 10.0, 200.0, 51.8], [1.0, 10.0, 200.0, 51.8], [2.0, 10.0, 200.0, 51.8], [0.0, 10.0, 200.0, 96.2], [1.0, 10.0, 200.0, 96.2], [2.0, 10.0, 200.0, 96.2], [0.0, 10.0, 200.0, 170.1], [1.0, 10.0, 200.0, 170.1], [2.0, 10.0, 200.0, 170.1], [0.0, 10.0, 500.0, 7.0], [1.0, 10.0, 500.0, 7.0], [2.0, 10.0, 500.0, 7.0], [0.0, 10.0, 500.0, 21.2], [1.0, 10.0, 500.0, 21.2], [2.0, 10.0, 500.0, 21.2], [0.0, 10.0, 500.0, 43.2], [1.0, 10.0, 500.0, 43.2], [1.0, 10.0, 700.0, 4.9], [2.0, 10.0, 700.0, 4.9], [0.0, 10.0, 700.0, 14.3], [1.0, 10.0, 700.0, 14.3], [2.0, 10.0, 700.0, 14.3], [2.0, 10.0, 500.0, 43.2], [0.0, 10.0, 500.0, 79.1], [1.0, 10.0, 500.0, 79.1], [2.0, 10.0, 500.0, 79.1], [0.0, 10.0, 700.0, 4.8], [0.0, 10.0, 700.0, 29.7], [1.0, 10.0, 700.0, 29.7], [2.0, 10.0, 700.0, 29.7], [0.0, 10.0, 700.0, 55.3], [1.0, 10.0, 700.0, 55.3], [2.0, 10.0, 700.0, 55.3], [0.0, 10.0, 1000.0, 3.92], [1.0, 10.0, 1000.0, 3.92], [2.0, 10.0, 1000.0, 3.92], [0.0, 10.0, 1000.0, 11.7], [1.0, 10.0, 1000.0, 11.7], [2.0, 10.0, 1000.0, 11.7], [0.0, 10.0, 1000.0, 25.2], [1.0, 10.0, 1000.0, 25.2], [2.0, 10.0, 1000.0, 25.2], [0.0, 10.0, 1000.0, 41.6], [1.0, 10.0, 1000.0, 41.6], [2.0, 10.0, 1000.0, 41.6]]
# [[ 0.83408885  1.58295558]
#  [ 0.50589302  1.16409791]
#  [ 0.50589302  0.58204896]
#  [ 0.83408885  0.74161378]
#  [ 1.66999093  2.97189483]
#  [ 1.07887579  1.24206709]
#  [ 0.83408885  0.39891206]
#  [ 1.66999093  1.59927471]
#  [ 2.00543971  2.30643699]
#  [ 0.83408885  0.22484134]
#  [ 1.66999093  0.90480508]
#  [ 3.33998187  3.61922031]
#  [ 0.87760653  6.07978241]
#  [ 0.37715322  2.25385313]
#  [ 0.37715322  1.12601995]
#  [ 0.87760653  2.00725295]
#  [ 1.75521306  8.03082502]
#  [ 1.14415231  3.41251133]
#  [ 0.87760653  0.98458749]
#  [ 1.75702629  3.94016319]
#  [ 2.33363554  6.9555757 ]
#  [ 0.87760653  0.53671804]
#  [ 1.75521306  2.15231188]
#  [ 3.51223935  8.60924751]
#  [ 0.89392566  8.99546691]
#  [ 0.36990027  3.10426111]
#  [ 0.36990027  1.55213055]
#  [ 0.89392566  3.08068903]
#  [ 1.78785131 12.32819583]
#  [ 1.08250227  4.5294651 ]
#  [ 0.89392566  1.48322756]
#  [ 1.78785131  5.93653672]
#  [ 2.25022665  9.40888486]
#  [ 0.89401632  0.79601088]
#  [ 1.78785131  3.18766999]
#  [ 3.57570263 12.7524932 ]
#  [ 0.92112421 11.94741614]
#  [ 0.41885766  4.94832276]
#  [ 0.41885766  2.47325476]
#  [ 0.92112421  4.00181324]
#  [ 1.84224841 16.01269266]
#  [ 1.25113327  7.38349955]
#  [ 0.92112421  1.85856754]
#  [ 1.84224841  7.43427017]
#  [ 2.69446963 15.9057117 ]
#  [ 0.92112421  1.12420671]
#  [ 1.84224841  4.50226655]
#  [ 3.68449683 18.01450589]]

# %%
#task 2.1 b)
import random

num_list = random.sample(range(0, ND), round(ND*0.25))

training_input=[]
training_output=[]
validation_input=[]
validation_output=[]

for i in range(ND):
    if num_list.count(i)==0:
        training_input.append(xarray[i,[1,2,3]])
        training_output.append(yarray[i,:])
    else:
        validation_input.append(xarray[i,:])
        validation_output.append(yarray[i,:])
training_input= numpy.array(training_input)
training_output= numpy.array(training_output)
validation_input= numpy.array(validation_input)
validation_output= numpy.array(validation_output)

print('training',training_input)
print('validation',training_output)
# Out:
# training [[1.         0.33333333 0.0405    ]
#  [1.         0.33333333 0.08633333]
#  [1.         0.33333333 0.08633333]
#  [1.         0.33333333 0.16033333]
#  [1.         0.33333333 0.16033333]
#  [1.         0.33333333 0.16033333]
#  [1.         0.33333333 0.2835    ]
#  [1.         0.33333333 0.2835    ]
#  [1.         0.83333333 0.01166667]
#  [1.         0.83333333 0.01166667]
#  [1.         0.83333333 0.03533333]
#  [1.         0.83333333 0.03533333]
#  [1.         0.83333333 0.03533333]
#  [1.         0.83333333 0.072     ]
#  [1.         0.83333333 0.072     ]
#  [1.         1.16666667 0.00816667]
#  [1.         1.16666667 0.00816667]
#  [1.         1.16666667 0.02383333]
#  [1.         1.16666667 0.02383333]
#  [1.         0.83333333 0.072     ]
#  [1.         0.83333333 0.13183333]
#  [1.         0.83333333 0.13183333]
#  [1.         1.16666667 0.008     ]
#  [1.         1.16666667 0.0495    ]
#  [1.         1.16666667 0.0495    ]
#  [1.         1.16666667 0.09216667]
#  [1.         1.16666667 0.09216667]
#  [1.         1.66666667 0.00653333]
#  [1.         1.66666667 0.00653333]
#  [1.         1.66666667 0.00653333]
#  [1.         1.66666667 0.0195    ]
#  [1.         1.66666667 0.042     ]
#  [1.         1.66666667 0.042     ]
#  [1.         1.66666667 0.06933333]
#  [1.         1.66666667 0.06933333]
#  [1.         1.66666667 0.06933333]]
# validation [[ 0.50589302  0.58204896]
#  [ 0.83408885  0.74161378]
#  [ 1.07887579  1.24206709]
#  [ 0.83408885  0.39891206]
#  [ 1.66999093  1.59927471]
#  [ 2.00543971  2.30643699]
#  [ 0.83408885  0.22484134]
#  [ 1.66999093  0.90480508]
#  [ 0.37715322  2.25385313]
#  [ 0.37715322  1.12601995]
#  [ 0.87760653  2.00725295]
#  [ 1.75521306  8.03082502]
#  [ 1.14415231  3.41251133]
#  [ 0.87760653  0.98458749]
#  [ 1.75702629  3.94016319]
#  [ 2.33363554  6.9555757 ]
#  [ 0.87760653  0.53671804]
#  [ 3.51223935  8.60924751]
#  [ 0.89392566  8.99546691]
#  [ 0.36990027  3.10426111]
#  [ 0.36990027  1.55213055]
#  [ 0.89392566  3.08068903]
#  [ 1.08250227  4.5294651 ]
#  [ 0.89392566  1.48322756]
#  [ 1.78785131  5.93653672]
#  [ 0.89401632  0.79601088]
#  [ 1.78785131  3.18766999]
#  [ 0.92112421 11.94741614]
#  [ 0.41885766  4.94832276]
#  [ 0.41885766  2.47325476]
#  [ 0.92112421  4.00181324]
#  [ 1.84224841  7.43427017]
#  [ 2.69446963 15.9057117 ]
#  [ 0.92112421  1.12420671]
#  [ 1.84224841  4.50226655]
#  [ 3.68449683 18.01450589]]

# %%
'''>>>>> start CodeP3.2.1F23
V.P. Carey ME249, Fall 2023
Intro to Neural Network Modeling
Keras model for PV power system'''
#import useful packages
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf
#the following 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# define meadian values of input variables - add your values here
#Tamed = 1. #make sure Tamed does not = 0
#IDmed = 1.
#RLmed = 1.
#create input data array
#xdata = []
#Part 1 input data: Mode number, Air temp (degC), ID (W/sqm), load resistance (ohms)
#xdata = [[0., 10.0, 200.0, 24.3]]
#xdata.append([1., 10.0, 200.0, 24.3])
#xdata.append([2., 10.0, 200.0, 24.3])
''' ADD THE REST OF THE INPUT DATA FROM DS3.2.1multiModePerfF23 AND CONVERT TO:
xdata = [[0., 10.0/Tamed, 200.0/IDmed, 24.3/RLmed]]
xdata.append([1., 10.0/Tamed, 200.0/IDmed, 24.3/RLmed])
xdata.append([2., 10.0/Tamed, 200.0/IDmed, 24.3/RLmed])
... etc.'''
#xarray= np.array(xdata)
#print (xdata)
#3print (xarray)
# define meadian values of output variables - add your values here
#VLmed = 1.
#Wdmed = 1
#create output data array
#ydata = []
#Part 1 output data: VL (V) and Power out Wd (W)
#ydata = [[46.0, 87.3]]
#ydata.append([27.9, 64.2])
#ydata.append([27.9, 32.1])
#ydata.append([46.0, 40.9])
''' ADD THE REST OF THE OUPUT DATA AND CONVERT TO:
ydata = [[46.0/VLmed, 87.3Wdmed]]
ydata.append([27.9/VLmed, 64.2Wdmed])
ydata.append([27.9/VLmed, 32.1Wdmed])
ydata.append([46.0/VLmed, 40.9Wdmed])
... etc.'''
#yarray= np.array(ydata)
#print (yarray)


xarray=training_input
yarray=training_output

data_inputs = xarray
data_outputs = yarray

# %%
# define neural network model
#As seen below, we have created four dense layers.
#A dense layer is a layer in neural network that’s fully connected.
#In other words, all the neurons in one layer are connected to all other neurons in the next layer.
#In the first layer, we need to provide the input shape, which is 1 in our case.
#The activation function we have chosen is elu, which stands for exponential linear unit. .
from keras import backend as K
#initialize weights with values between -0.2 and 0.5
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)
model = keras.Sequential([
keras.layers.Dense(13, activation=K.elu, input_shape=[3], kernel_initializer=initializer),
keras.layers.Dense(26, activation=K.elu, kernel_initializer=initializer),
keras.layers.Dense(13, activation=K.elu, kernel_initializer=initializer),
keras.layers.Dense(2, kernel_initializer=initializer)
])

# %%
#We’re using RMSprop as our optimizer here. RMSprop stands for Root Mean Square Propagation.
#It’s one of the most popular gradient descent optimization algorithms for deep learning networks.
#RMSprop is an optimizer that’s reliable and fast.
#We’re compiling the mode using the model.compile function. The loss function used here
#is mean squared error. After the compilation of the model, we’ll use the fit method with ~500 epochs.
#Number of epochs can be varied.
#from tf.keras import optimizers
rms = keras.optimizers.RMSprop(0.020)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
#After the compilation of the model, we’ll use the fit method with 500 epochs.
#I started with epochs value of 100 and then tested the model after training.
#The prediction was not that good. Then I modified the number of epochs to 200 and tested the model again.
#Accuracy had improved slightly, but figured I’d give it one more try. Finally, at 500 epochs
#I found acceptable prediction accuracy.
#The fit method takes three parameters; namely, x, y, and number of epochs.
#During model training, if all the batches of data are seen by the model once,
#we say that one epoch has been completed.
# Add an early stopping callback

es = keras.callbacks.EarlyStopping(
monitor='loss',
mode='min',
patience = 80,
restore_best_weights = True,
verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss',
mode='min', verbose=1, save_best_only=True)
historyData = model.fit(xarray,yarray,epochs=800,callbacks=[es])
loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))
model.save('./best_model')
predictions = model.predict(data_inputs)
# Out:
# Epoch 1/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5113
# Epoch 2/800
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4784
# Epoch 3/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5308
# Epoch 4/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4881
# Epoch 5/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5637
# Epoch 6/800
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4727
# Epoch 7/800
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5053
# Epoch 8/800
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5079
# Epoch 9/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4922
# Epoch 10/800
# 2/2 [==============================] - 0s 746us/step - loss: 1.5332
# Epoch 11/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4833
# Epoch 12/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5329
# Epoch 13/800
# 2/2 [==============================] - 0s 968us/step - loss: 1.4705
# Epoch 14/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4739
# Epoch 15/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4773
# Epoch 16/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5129
# Epoch 17/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.
800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4787
# Epoch 103/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4943
# Epoch 104/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.5216
# Epoch 105/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4800
# Epoch 106/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5334
# Epoch 107/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5576
# Epoch 108/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5024
# Epoch 109/800
# 2/2 [==============================] - 0s 576us/step - loss: 1.4770
# Epoch 110/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4844
# Epoch 111/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.5081
# Epoch 112/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4752
# Epoch 113/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4704
# Epoch 114/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4975
# Epoch 115/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5067
# Epoch 116/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4764
# Epoch 117/800
# 2/2 [==============================] - 0s 518us/step - loss: 1.5544
# Epoch 118/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5860
# Epoch 119/800
# 2/2 [==============================] - 0s 847us/step - loss: 1.4692
# Epoch 120/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4811
# Epoch 121/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4852
# Epoch 122/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4809
# Epoch 123/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4720
# Epoch 124/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4781
# Epoch 125/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.5140
# Epoch 126/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4737
# Epoch 127/800
# 2/2 [==============================] - 0s 830us/step - loss: 1.4724
# Epoch 128/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4774
# Epoch 129/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.5136
# Epoch 130/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4877
# Epoch 131/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4883
# Epoch 132/800
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4892
# Epoch 133/800
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4809
# Epoch 134/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4927
# Epoch 135/800
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4781
# Epoch 136/800
# 2/2 [==============================] - 0s 693us/step - loss: 1.4956
# Epoch 137/800
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4859
# Epoch 138/800
# 2/2 [==============================] - 0s 0s/step - loss: 1.4685
# Epoch 139/800
# 2/2 [==============================] - 0s 572us/step - loss: 1.4740
# Epoch 140/800
# 1/2 [==============>...............] - ETA: 0s - loss: 1.5784Restoring model weights from the end of the best epoch.
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4912
# Epoch 00140: early stopping
# best epoch =  60
# smallest loss = 1.4675204753875732
# INFO:tensorflow:Assets written to: ./best_model\assets

# %%
# This line of code can be used to reconstruct the saved model.
recon_model = keras.models.load_model("best_model")
# the name of the model is now "recon_model". You can then use this model to do predictions for comparisons.
# See the previous project for code to do the comparisons.

# %%
 import matplotlib.pyplot as plt
    
y=predictions[:,1]
x=data_outputs[:,1]
    
corr_coeff = np.corrcoef(y, x)
correlation_coeff_value = corr_coeff[0][1]
display(correlation_coeff_value)
r_square_value = correlation_coeff_value ** 0.5

    #x= outputs_experimental['a']
#y = outputs_predicted_df['a']

#coefficients = np.polyfit(np.log(x), np.log(y), 1)
#line_function = np.poly1d(coefficients)

# Create a range for predicted values for the fit line
#x_vals = np.linspace(min(x), max(y), 400)
#y_vals = np.exp(line_function(np.log(x_vals)))



#best fit line and y = x line
plt.scatter(x, y, c='red', marker='x')
#plt.plot(x_vals, y_vals, color='red', label=f'Fit: y = {coefficients[0]:.2f}x + {coefficients[1]:.2f}')
plt.axline((0, 0), (1,1),color='black',linestyle='--', label=f'y=x, R^2 = {r_square_value}',)

#visuals
font_family = 'Times New Roman'
title_font_size=17
label_font_size=15
legend_tick_font_size=12

plt.title('Predicted power output against Data value power', fontsize=title_font_size, fontfamily=font_family)
plt.xlabel('Data value power', fontsize=label_font_size, fontfamily=font_family)
plt.ylabel('Predicted power output', fontsize=label_font_size, fontfamily=font_family)

plt.legend(fontsize = legend_tick_font_size)
plt.loglog()
#plt.xlim(xmax=150, xmin=30)
#plt.ylim(ymax=150, ymin=30)

plt.show()
# Out:
# 0.577461005463398
